# %%
import joblib

model = joblib.load("placement_random_forest_model.pkl")

# %%
print(type(model))
print(model)
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# RandomForestClassifier(max_depth=8, min_samples_split=10, n_jobs=-1,
#                        random_state=42)
